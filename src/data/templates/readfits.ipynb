# %%
from astropy.io import fits
import matplotlib.pyplot as plt
fname = 'F2_-1.0_Dwarf.fits'

# %%
fit = fits.open(fname)
fit.info()
# Out:
# Filename: F2_-1.0_Dwarf.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       7   ()
#   1                1 BinTableHDU     16   61618R x 4C   [E, E, E, E]
#   2                1 BinTableHDU     20   3R x 6C   [E, E, E, E, E, E]

# %%
# fit[0].data.shape
print(fit[1].data.shape)
print(fit[2].data.shape)
fit[2].data
data = fit[1].data
fit[1].header
# Out:
# (61618,)
# (3,)
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                   16 / length of dimension 1
# NAXIS2  =                61618 / length of dimension 2
# PCOUNT  =                    0 / number of group parameters
# GCOUNT  =                    1 / number of groups
# TFIELDS =                    4 / number of table fields
# TTYPE1  = 'LogLam  '
# TFORM1  = 'E       '
# TTYPE2  = 'Flux    '
# TFORM2  = 'E       '
# TTYPE3  = 'PropErr '
# TFORM3  = 'E       '
# TTYPE4  = 'Std     '
# TFORM4  = 'E       '

# %%
wave = 10**data['LogLam']
flux = data['Flux']
err1 = data['PropErr']
err2 = data['Std']

# %%
plt.plot(wave, flux)

# %%
plt.plot(wave, err1)
plt.plot(wave, err2*0.2)

# %%
fit = fits.open('/home/zzx/software/PyHammer/test_case/spec-4961-55719-0378.fits')
fit.info()
# Out:
# Filename: /home/zzx/software/PyHammer/test_case/spec-4961-55719-0378.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     131   ()
#   1  COADD         1 BinTableHDU     26   4619R x 8C   [E, E, E, J, J, E, E, E]
# ...

# %%
fit[1].data
# Out:
# FITS_rec([(79.370735, 3.5526, 0.00351815, 0, 71303168, 1.0846379, 22.330688, 82.08335 ),
#           (73.01383 , 3.5527, 0.02241104, 0,        0, 1.0850153, 14.128526, 82.588715),
#           (75.78077 , 3.5528, 0.02458848, 0,        0, 1.0854384, 13.659307, 83.441574),
#           ...,
#           (24.615923, 4.0142, 0.12333435, 0,   851968, 0.8307637,  6.337823, 23.226507),
#           (26.312815, 4.0143, 0.08453737, 0,    65536, 0.831382 ,  8.35386 , 23.24717 ),
#           (26.678104, 4.0144, 0.07046974, 0,        0, 0.831995 , 10.074572, 23.075312)],
#          dtype=(numpy.record, [('flux', '>f4'), ('loglam', '>f4'), ('ivar', '>f4'), ('and_mask', '>i4'), ('or_mask', '>i4'), ('wdisp', '>f4'), ('sky', '>f4'), ('model', '>f4')]))

# %%
fit[1].header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                   32 / length of dimension 1
# NAXIS2  =                 4619 / length of dimension 2
# PCOUNT  =                    0 / number of group parameters
# GCOUNT  =                    1 / number of groups
# TFIELDS =                    8 / number of table fields
# TTYPE1  = 'flux    '
# TFORM1  = 'E       '
# TTYPE2  = 'loglam  '
# TFORM2  = 'E       '
# TTYPE3  = 'ivar    '
# TFORM3  = 'E       '
# TTYPE4  = 'and_mask'
# TFORM4  = 'J       '
# TTYPE5  = 'or_mask '
# TFORM5  = 'J       '
# TTYPE6  = 'wdisp   '
# TFORM6  = 'E       '
# TTYPE7  = 'sky     '
# TFORM7  = 'E       '
# TTYPE8  = 'model   '
# TFORM8  = 'E       '
# EXTNAME = 'COADD   '
# COMMENT Coadded spectrum

# %%
fit[2].header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                 3982 / length of dimension 1
# NAXIS2  =                    1 / length of dimension 2
# PCOUNT  =                    0 / number of group parameters
# GCOUNT  =                    1 / number of groups
# TFIELDS =                  232 / number of table fields
# TTYPE1  = 'PROGRAMNAME'
# TFORM1  = '27A     '
# TTYPE2  = 'CHUNK   '
# TFORM2  = '14A     '
# TTYPE3  = 'PLATEQUALITY'
# TFORM3  = '4A      '
# TTYPE4  = 'PLATESN2'
# TFORM4  = 'E       '
# TTYPE5  = 'DEREDSN2'
# TFORM5  = 'E       '
# TTYPE6  = 'PRIMTARGET'
# TFORM6  = 'J       '
# TTYPE7  = 'SECTARGET'
# TFORM7  = 'J       '
# TTYPE8  = 'LAMBDA_EFF'
# TFORM8  = 'E       '
# TTYPE9  = 'BLUEFIBER'
# TFORM9  = 'J       '
# TTYPE10 = 'ZOFFSET '
# TFORM10 = 'E       '
# TTYPE11 = 'XFOCAL  '
# TFORM11 = 'E       '
# TTYPE12 = 'YFOCAL  '
# ...
